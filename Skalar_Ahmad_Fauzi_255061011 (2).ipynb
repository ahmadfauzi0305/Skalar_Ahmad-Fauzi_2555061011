# %%
# buat variasi skalar x dan simpan suatu nilao skalar
x = 11

# %%
# tampilkan type data x
type(x)
# Out:
# int

# %%
# buat variabel skalar dan simpan suatu nilai skalar
y = 11

# %%
#tampilkan variabel skalar dan simpan suatu nilai skalar
type(y)
# Out:
# int

# %%
# jumlahkan x_float dengan y
py_sum = x + y
py_sum
# Out:
# 22

# %%
# buat variabel bernama x_float dan simpan suatu nilai desimal
x_float = 2555.0

# %%
# jumlahkan x_float dengan y
float_sum = x_float + y
float_sum
# Out:
# 2566.0

# %%
# tampilkan tipe data dari x_float
type(x_float)
# Out:
# float

# %%
import tensorflow as tf

# %%
# lakukan tahapan pada soal 1 dengan menggunakan tensorflow
x_tf = tf.Variable(11, dtype=tf.int16)
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int16, numpy=11>

# %%
import torch

# %%
# lakukan tahapan pada soal 1 dengan menggunakan pytorch
x_pt = torch.tensor(11)
x_pt
# Out:
# tensor(11)
